# %%
from sklearn.neighbors import NearestNeighbors as NN
from sklearn.neighbors import NearestCentroid as NC
from sklearn.neighbors import KNeighborsClassifier as KNC
from sklearn.metrics import accuracy_score
from sklearn.manifold import TSNE
from xgboost import XGBClassifier as XGBC
from sklearn.model_selection import train_test_split
from collections import Counter
import numpy as np
import pandas as pd
import glob, os, random

# %%
df_song_species = pd.read_csv('../preprocess_data/species_and_record_url.csv')
species = pd.read_csv('../preprocess_data/species_keys.csv')

# %%
emb_ids = []
avg_embs = []
labels = []
bird_embs = glob.glob('../avg_bird_embeddings/*')
random.shuffle(bird_embs)
for avg_emb_path in bird_embs:
    emb_id = os.path.basename(avg_emb_path).replace('.npy','')
    emb_id = int(emb_id)

    # load d-vector
    avg_emb = np.load(avg_emb_path)
    
    # get species id for embedding
    label = df_song_species.loc[df_song_species['recording_id'] == emb_id, 'species_id'].values[0]

    emb_ids.append(emb_id)
    avg_embs.append(avg_emb)
    labels.append(label)
    
avg_embs = np.array(avg_embs)
labels = np.array(labels)
print('Number of Unique Species:', np.unique(labels).shape[0])
print('Samps per Species:', Counter(labels))
# Out:
# Number of Unique Species: 889
# Samps per Species: Counter({4017: 141, 7439: 59, 3376: 39, 2833: 30, 3981: 25, 3533: 18, 7241: 17, 6615: 16, 556: 16, 2872: 16, 9191: 16, 6940: 16, 6392: 13, 7343: 13, 4591: 12, 9336: 12, 3596: 12, 1111: 12, 7948: 12, 7156: 12, 3714: 12, 9061: 11, 3372: 11, 8229: 11, 7479: 11, 2711: 11, 4962: 11, 64: 10, 2256: 10, 7248: 10, 1164: 10, 9249: 10, 1501: 10, 9270: 10, 8545: 9, 7953: 9, 8793: 9, 2294: 9, 4882: 9, 6556: 9, 8235: 9, 7669: 9, 3524: 9, 7357: 9, 7373: 9, 1183: 9, 8228: 9, 3628: 9, 2284: 9, 3194: 9, 3526: 9, 786: 8, 8129: 8, 9073: 8, 3845: 8, 735: 8, 1171: 8, 6358: 8, 4277: 8, 2835: 8, 6189: 8, 7598: 8, 1737: 8, 4476: 8, 7834: 8, 4482: 8, 3319: 8, 7920: 7, 1097: 7, 3544: 7, 3327: 7, 1210: 7, 575: 7, 3120: 7, 1575: 7, 6008: 7, 9349: 7, 5829: 7, 6280: 7, 6323: 7, 6057: 7, 5936: 7, 6425: 7, 7615: 7, 4380: 7, 8410: 7, 5207: 7, 8494: 7, 6831: 7, 8619: 6, 9201: 6, 530: 6, 7433: 6, 2117: 6, 8045: 6, 1010: 6, 9364: 6, 6822: 6, 1311: 6, 1588: 6, 6751: 6, 2071: 6, 8385: 6, 2830: 6, 2092: 6, 1490: 6, 8563: 6, 2520: 6, 2316: 6, 8549: 6, 9464: 6, 2309: 6, 2719: 6, 8868: 6, 1643: 6, 8782: 6, 1347: 6, 6665: 6, 3527: 6, 3532: 5, 5429: 5, 6997: 5, 4455: 5, 4413: 5, 6241: 5, 7510: 5, 5390: 5, 5757: 5, 8248: 5, 1843: 5, 8067: 5, 3827: 5, 220: 5, 5059: 5, 4693: 5, 4777: 5, 5516: 5, 2678: 5, 1249: 5, 7452: 5, 9357: 5, 8669: 5, 3181: 5, 3966: 5, 7825: 5, 2844: 5, 4593: 5, 909: 5, 3482: 5, 8142: 5, 2866: 5, 9376: 5, 309: 5, 2274: 5, 7355: 5, 2474: 5, 2864: 5, 1031: 5, 8080: 5, 1398: 5, 1985: 4, 1763: 4, 7048: 4, 5417: 4, 2508: 4, 4266: 4, 3443: 4, 8638: 4, 9038: 4, 7331: 4, 7121: 4, 9281: 4, 12: 4, 798: 4, 7736: 4, 3243: 4, 8517: 4, 9237: 4, 6319: 4, 6513: 4, 1834: 4, 1564: 4, 300: 4, 2988: 4, 560: 4, 7230: 4, 4748: 4, 713: 4, 4583: 4, 4031: 4, 8306: 4, 2640: 4, 305: 4, 318: 4, 4816: 4, 1056: 4, 7944: 4, 2644: 4, 2235: 4, 886: 4, 3487: 4, 139: 4, 7436: 4, 7143: 4, 6943: 4, 5276: 4, 5208: 4, 3249: 4, 8033: 4, 6969: 4, 8203: 4, 7784: 4, 4281: 3, 7082: 3, 2501: 3, 6988: 3, 4598: 3, 8338: 3, 6538: 3, 440: 3, 4511: 3, 1022: 3, 5875: 3, 94: 3, 8052: 3, 6287: 3, 8985: 3, 4312: 3, 9210: 3, 7625: 3, 5254: 3, 4448: 3, 5847: 3, 324: 3, 1645: 3, 785: 3, 9318: 3, 5585: 3, 1317: 3, 161: 3, 3620: 3, 5849: 3, 5421: 3, 990: 3, 176: 3, 2201: 3, 6783: 3, 5835: 3, 7406: 3, 620: 3, 55: 3, 4559: 3, 3066: 3, 4623: 3, 1855: 3, 2173: 3, 524: 3, 2365: 3, 7513: 3, 9259: 3, 1452: 3, 7748: 3, 8308: 3, 5250: 3, 2383: 3, 5609: 3, 6970: 3, 8612: 3, 1691: 3, 7113: 3, 8034: 3, 2445: 3, 4028: 3, 3068: 3, 5304: 3, 6800: 3, 1798: 3, 4410: 3, 7117: 3, 6248: 3, 7318: 3, 9099: 3, 5974: 3, 1179: 3, 2297: 3, 2600: 3, 9258: 3, 7100: 3, 2170: 3, 1963: 3, 2480: 3, 1835: 3, 3349: 3, 4501: 3, 2012: 3, 1595: 3, 8536: 3, 2893: 3, 2448: 3, 9035: 3, 2023: 3, 6506: 3, 8824: 3, 8081: 3, 3614: 3, 719: 3, 140: 3, 8354: 3, 2312: 3, 5326: 3, 8922: 3, 5725: 3, 6076: 3, 8073: 3, 4391: 3, 5842: 3, 966: 3, 3310: 2, 9238: 2, 3562: 2, 2804: 2, 9361: 2, 6956: 2, 8917: 2, 349: 2, 5040: 2, 6775: 2, 7307: 2, 968: 2, 4715: 2, 2287: 2, 7969: 2, 3788: 2, 8892: 2, 9109: 2, 8190: 2, 2258: 2, 669: 2, 7261: 2, 1624: 2, 1036: 2, 7647: 2, 1418: 2, 6720: 2, 2388: 2, 2638: 2, 6519: 2, 4789: 2, 2916: 2, 1811: 2, 5318: 2, 8754: 2, 422: 2, 656: 2, 2281: 2, 2404: 2, 543: 2, 3879: 2, 3854: 2, 4637: 2, 5708: 2, 7663: 2, 5277: 2, 3805: 2, 2891: 2, 6851: 2, 77: 2, 292: 2, 8040: 2, 428: 2, 7770: 2, 2930: 2, 6960: 2, 7478: 2, 2707: 2, 5123: 2, 5540: 2, 3257: 2, 7231: 2, 3678: 2, 2459: 2, 2393: 2, 6451: 2, 7599: 2, 5606: 2, 7603: 2, 8872: 2, 1102: 2, 6359: 2, 3797: 2, 6249: 2, 1744: 2, 3164: 2, 2328: 2, 3654: 2, 8321: 2, 6756: 2, 5707: 2, 755: 2, 7468: 2, 2980: 2, 5051: 2, 1004: 2, 8620: 2, 2315: 2, 3587: 2, 5641: 2, 4505: 2, 2136: 2, 5264: 2, 8307: 2, 271: 2, 8982: 2, 9334: 2, 1338: 2, 1925: 2, 4767: 2, 5424: 2, 5174: 2, 569: 2, 6175: 2, 3258: 2, 5607: 2, 172: 2, 3698: 2, 3432: 2, 9027: 2, 7549: 2, 1606: 2, 5143: 2, 3630: 2, 7459: 2, 8702: 2, 103: 2, 3021: 2, 8823: 2, 308: 2, 9269: 2, 7395: 2, 2500: 2, 424: 2, 150: 2, 852: 2, 5242 ...

# %%
# fit nearest_neighbors
nn = NN(n_neighbors=6, metric='euclidean', n_jobs=-1)
nn.fit(avg_embs)
dists, inds = nn.kneighbors(avg_embs)

# %%
data_neighbors = []
count = 0
for neighbor_matches, dist_matches in zip(inds.tolist(), dists.tolist()):
    neighbor_row = []
    for n, dist in zip(range(0, len(neighbor_matches)), dist_matches):
        emb_id = emb_ids[neighbor_matches[n]]

        # get species of embedding
        species_id = df_song_species.loc[df_song_species['recording_id'] == emb_id, 'species_id'].values[0]
        species_name = species.loc[species['species_id'] == species_id, 'common_name'].values[0]
        neighbor_row.append(str(emb_id) + '.wav')
        neighbor_row.append(dist)
        neighbor_row.append(species_name)

    # append neighbors row to main data list
    data_neighbors.append(neighbor_row)

cols = [
    'Orignal_Recording', 'Original_Distance', 'Original_Common_Name',
    '1st_Neighbor_Recording', '1st_Neighbor_Distance', '1st_Neighbor_Common_Name',
    '2nd_Neighbor_Recording', '2nd_Neighbor_Distance', '2nd_Neighbor_Common_Name',
    '3rd_Neighbor_Recording', '3rd_Neighbor_Distance', '3rd_Neighbor_Common_Name',
    '4th_Neighbor_Recording', '4th_Neighbor_Distance', '4th_Neighbor_Common_Name',
    '5th_Neighbor_Recording', '5th_Neighbor_Distance', '5th_Neighbor_Common_Name']

df_neighbors = pd.DataFrame(data_neighbors, columns=cols)
df_neighbors.head(10)
# Out:
#   Orignal_Recording  Original_Distance           Original_Common_Name  \
# 0         22498.wav                0.0                  Common Cuckoo
# 1         22569.wav                0.0        Red-cockaded Woodpecker
# 2         53635.wav                0.0  Rusty-fronted Tody-Flycatcher
# 3         53820.wav                0.0               White-eyed Vireo
# 4           398.wav                0.0                Piping Hornbill
# 5         64959.wav                0.0                  House Sparrow
# 6         21892.wav                0.0           Tropical Screech Owl
# 7         33143.wav                0.0            European Greenfinch
# 8         21473.wav                0.0          White-necked Puffbird
# 9         64522.wav                0.0                Long-tailed Tit
#
#   1st_Neighbor_Recording  1st_Neighbor_Distance  \
# 0              22497.wav               0.497725
# 1              11482.wav               0.322953
# 2               1283.wav               0.483253
# 3              53787.wav               0.316916
# 4                738.wav               0.226663
# 5              64961.wav               0.478789
# 6              43205.wav               0.434623
# 7                625.wav               0.445147
# 8                321.wav               0.398312
# 9              64986.wav               0.000000
#
#             1st_Neighbor_Common_Name 2nd_Neighbor_Recording  \
# 0                      Common Cuckoo              32894.wav
# 1               White-bibbed Manakin              11481.wav
# 2                    Spangled Drongo              21533.wav
# 3                       Caspian Tern              53786.wav
# 4           Eastern Bearded Greenbul              75867.wav
# 5                            Redwing              64832.wav
# 6               Tropical Screech Owl              32550.wav
# 7                  Johanna's Sunbird              64624.wav
# 8  Rufous-vented Paradise Flycatcher                319.wav
# 9                    Long-tailed Tit              64895.wav
#
#    2nd_Neighbor_Distance           2nd_Neighbor_Common_Name  \
# 0               0.504404                      Common Cuckoo
# 1               0.322953               White-bibbed Manakin
# 2               0.492693                 Rio Branco Antbird
# 3               0.406880                       Caspian Tern
# 4               0.226663         Fire-breasted Flowerpecker
# 5               0.478789                            Redwing
# 6               0.480303               Tropical Screech Owl
# 7               0.594906                      Dusky Warbler
# 8               0.452216  Rufous-vented Paradise Flycatcher
# 9               0.000000                    Long-tailed Tit
#
#   3rd_Neighbor_Recording  3rd_Neighbor_Distance   3rd_Neighbor_Common_Name  \
# 0              22500.wav               0.524576              Common Cuckoo
# 1              11480.wav               0.322953       White-bibbed Manakin
# 2               1282.wav               0.500347            Spangled Drongo
# 3              53834.wav               0.455478        Common Yellowthroat
# 4                 94.wav               0.233958      Yellow-spotted Barbet
# 5              43401.wav               0.651307         Black-winged Stilt
# 6              32548.wav               0.480804       Tropical Screech Owl
# 7              12198.wav               0.610507              Dusky Warbler
# 8                785.wav               0.479017  Chestnut-breasted Nigrita
# 9              43526.wav               0.499681                  Great Tit
#
#   4th_Neighbor_Recording  4th_Neighbor_Distance  \
# 0              21577.wav               0.677400
# 1              12048.wav               0.322953
# 2              33556.wav               0.543564
# 3              53812.wav               0.460618
# 4                 93.wav               0.264513
# 5              75091.wav               0.651307
# 6              32547.wav               0.521826
# 7              21609.wav               0.610843
# 8                320.wav               0.491552
# 9                 15.wav               0.500480
#
#             4th_Neighbor_Common_Name 5th_Neighbor_Recording  \
# 0                 Eurasian Bullfinch              43970.wav
# 1              White-tailed Nuthatch              22570.wav
# 2                Speckled Chachalaca              54554.wav
# 3               Northern Mockingbird              22232.wav
# 4              Yellow-spotted Barbet                 95.wav
# 5                 Black-winged Stilt              43692.wav
# 6               Tropical Screech Owl              76022.wav
# 7                 Erckel's Francolin              11991.wav
# 8  Rufous-vented Paradise Flycatcher                206.wav
# 9                    Long-tailed Tit              32951.wav
#
#    5th_Neighbor_Distance   5th_Neighbor_Common_Name
# 0               0.677400         Eurasian Bullfinch
# 1               0.498126        Pileated Woodpecker
# 2               0.649211  Yellow-crested Woodpecker
# 3               0.460618             Arctic Warbler
# 4               0.308983      Yellow-spotted Barbet
# 5               0.670663              House Sparrow
# 6               0.556843       Tropical Screech Owl
# 7               0.614526      Yellow-browed Warbler
# 8               0.497904            Western Nicator
# 9               0.523373            Long-tailed Tit

# %%
df_neighbors.sort_values(['1st_Neighbor_Distance'], ascending=[True]).head(10)
# Out:
#      Orignal_Recording  Original_Distance     Original_Common_Name  \
# 1522         22340.wav                0.0          Western Nicator
# 389          43700.wav                0.0                Great Tit
# 914          11835.wav                0.0             Palm Tanager
# 387          22248.wav                0.0       Eurasian Bullfinch
# 1650         54194.wav                0.0        Eurasian Blackcap
# 918          21575.wav                0.0      Costa's Hummingbird
# 922          65059.wav                0.0      Little Spiderhunter
# 383          33493.wav                0.0          Pacific Hornero
# 923          33521.wav                0.0  Streak-backed Canastero
# 1649         64930.wav                0.0               Soundscape
#
#      1st_Neighbor_Recording  1st_Neighbor_Distance  1st_Neighbor_Common_Name  \
# 1522              22335.wav                    0.0           Western Nicator
# 389               43378.wav                    0.0                 Great Tit
# 914                 685.wav                    0.0  Black-fronted Tyrannulet
# 387               10829.wav                    0.0        Eurasian Bullfinch
# 1650              33068.wav                    0.0         Eurasian Blackcap
# 918               53806.wav                    0.0             Carolina Wren
# 922               22492.wav                    0.0              Hazel Grouse
# 383               11713.wav                    0.0  Many-colored Rush Tyrant
# 923               33522.wav                    0.0   Streak-backed Canastero
# 1649              64434.wav                    0.0                Soundscape
#
#      2nd_Neighbor_Recording  2nd_Neighbor_Distance 2nd_Neighbor_Common_Name  \
# 1522              22321.wav               0.105565          Western Nicator
# 389               53764.wav               0.487504       Buff-bellied Pipit
# 914               11626.wav               0.000000             Palm Tanager
# 387               43056.wav               0.483096                  Redwing
# 1650              33065.wav               0.212476        Eurasian Blackcap
# 918               33011.wav               0.000000      Costa's Hummingbird
# 922               65058.wav               0.000000      Little Spiderhunter
# 383               33491.wav               0.269623          Pacific Hornero
# 923               33519.wav               0.443539  Streak-backed Canastero
# 1649              65078.wav               0.259089               Soundscape
#
#      3rd_Neighbor_Recording  3rd_Neighbor_Distance   3rd_Neighbor_Common_Name  \
# 1522              22319.wav               0.149552            Western Nicator
# 389               54439.wav               0.508170           Lesser Goldfinch
# 914                 696.wav               0.545444      White-chested Emerald
# 387               64655.wav               0.486640   Great Spotted Woodpecker
# 1650              33067.wav               0.222613          Eurasian Blackcap
# 918               54073.wav               0.000000        Costa's Hummingbird
# 922               43448.wav               0.000000   Dusky-throated Antshrike
# 383               33492.wav               0.290077            Pacific Hornero
# 923               33410.wav               0.453039  Rufous-webbed Bush Tyrant
# 1649              64439.wav               0.259089                 Soundscape
#
#      4th_Neighbor_Recording  4th_Neighbor_Distance  \
# 1522              22338.wav               0.189703
# 389               54056.wav               0.520842
# 914                1305.wav               0.665196
# 387               10835.wav               0.486640
# 1650              33066.wav               0.275850
# 918               75746.wav               0.543787
# 922               43450.wav               0.256313
# 383               33366.wav               0.373469
# 923               32917.wav               0.532450
# 1649              64437.wav               0.259089
#
#         4th_Neighbor_Common_Name 5th_Neighbor_Recording  \
# 1522     Grey-backed Camaroptera              22339.wav
# 389             Lesser Goldfinch                864.wav
# 914                 Manu Antbird              22107.wav
# 387     Great Spotted Woodpecker              64829.wav
# 1650           Eurasian Blackcap                 29.wav
# 918                Carolina Wren              53779.wav
# 922     Dusky-throated Antshrike                650.wav
# 383      D'Orbigny's Chat-Tyrant              76009.wav
# 923   Bright-rumped Yellow Finch              33649.wav
# 1649                  Soundscape              64438.wav
#
#       5th_Neighbor_Distance 5th_Neighbor_Common_Name
# 1522               0.261559  Grey-backed Camaroptera
# 389                0.561814      Black-winged Oriole
# 914                0.715074    Mountain Leaf Warbler
# 387                0.541591       Eurasian Bullfinch
# 1650               0.416855       Common Nightingale
# 918                0.546697              Horned Lark
# 922                0.350494  Grey-backed Camaroptera
# 383                0.422689          Pacific Hornero
# 923                0.532450        Streaked Saltator
# 1649               0.280885               Soundscape

# %%
orig_and_first = df_neighbors[[
    'Original_Common_Name', 
    '1st_Neighbor_Common_Name'
]].values

num_matches = np.where(
    (orig_and_first[:, 0] == orig_and_first[:, 1]) 
)
top_1_accuracy = num_matches[0].shape[0] / orig_and_first.shape[0]
print('Top 1 Accuracy:', top_1_accuracy)
# Out:
# Top 1 Accuracy: 0.4837328767123288

# %%
orig_and_first = df_neighbors[[
    'Original_Common_Name', 
    '1st_Neighbor_Common_Name', 
    '2nd_Neighbor_Common_Name',
    '3rd_Neighbor_Common_Name',
    '4th_Neighbor_Common_Name',
    '5th_Neighbor_Common_Name'
]].values

num_matches = np.where(
    (orig_and_first[:, 0] == orig_and_first[:, 1]) 
    | (orig_and_first[:, 0] == orig_and_first[:, 2])
    | (orig_and_first[:, 0] == orig_and_first[:, 3])
    | (orig_and_first[:, 0] == orig_and_first[:, 4])
    | (orig_and_first[:, 0] == orig_and_first[:, 5])
)
top_5_accuracy = num_matches[0].shape[0] / orig_and_first.shape[0]
print('Top 5 Accuracy:', top_5_accuracy)
# Out:
# Top 5 Accuracy: 0.6592465753424658

# %%
#tsne_embs = TSNE(n_components=2, perplexity=50).fit_transform(avg_embs)
x_train, x_test, y_train, y_test = train_test_split(avg_embs, labels, test_size=0.2)

# %% [markdown]
# ## Nearest Centroid Classification (nearest species)

# %%
#tsne_embs = TSNE(n_components=2).fit_transform(avg_embs)
nc = NC()
nc.fit(x_train, y_train)
print('NC Accuracy:', nc.score(x_test, y_test))
# Out:
# NC Accuracy: 0.38247863247863245

# %% [markdown]
# ## K Neighbors Classifier

# %%
knc = KNC(n_neighbors = 1, n_jobs=-1)
knc.fit(x_train, y_train)
print('KNC Accuracy:', knc.score(x_test, y_test))
# Out:
# KNC Accuracy: 0.4444444444444444

# %% [markdown]
# ## XGB Classifier

# %%
xgbc = XGBC(n_estimators=100)
xgbc.fit(x_train, y_train)
predicts = xgbc.predict(x_test)
print('XGBC Accuracy:', accuracy_score(y_test, predicts))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-38ace7f8abff> in <module>
#       1 xgbc = XGBC(n_estimators=100)
# ----> 2 xgbc.fit(x_train, y_train)
#       3 predicts = xgbc.predict(x_test)
#       4 print('XGBC Accuracy:', accuracy_score(y_test, predicts))
#
# ~/.local/lib/python3.6/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     730                               evals_result=evals_result, obj=obj, feval=feval,
#     731                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 732                               callbacks=callbacks)
#     733
#     734         self.objective = xgb_options["objective"]
#
# ~/.local/lib/python3.6/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# ~/.local/lib/python3.6/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# ~/.local/lib/python3.6/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# KeyboardInterrupt:
