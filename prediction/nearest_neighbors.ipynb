# %%
from sklearn.neighbors import NearestNeighbors as NN
import numpy as np
import pandas as pd
import glob, os, random

# %%
df_song_species = pd.read_csv('../preprocess_data/species_and_record_url.csv')
species = pd.read_csv('../preprocess_data/species_keys.csv')

# %%
emb_ids = []
avg_embs = []
bird_embs = glob.glob('../avg_bird_embeddings/*')
random.shuffle(bird_embs)
for avg_emb_path in bird_embs:
    emb_id = os.path.basename(avg_emb_path).replace('.npy','')
    emb_id = int(emb_id)

    # load d-vector
    avg_emb = np.load(avg_emb_path)

    emb_ids.append(emb_id)
    avg_embs.append(avg_emb)

avg_embs = np.array(avg_embs)

# %%
# fit nearest_neighbors
nn = NN(n_neighbors=6, metric='euclidean', n_jobs=-1)
nn.fit(avg_embs)
dists, inds = nn.kneighbors(avg_embs)

# %%
data_neighbors = []
count = 0
for neighbor_matches, dist_matches in zip(inds.tolist(), dists.tolist()):
    neighbor_row = []
    for n, dist in zip(range(0, len(neighbor_matches)), dist_matches):
        emb_id = emb_ids[neighbor_matches[n]]

        # get species of embedding
        species_id = df_song_species.loc[df_song_species['recording_id'] == emb_id, 'species_id'].values[0]
        species_name = species.loc[species['species_id'] == species_id, 'common_name'].values[0]
        neighbor_row.append(str(emb_id) + '.wav')
        neighbor_row.append(dist)
        neighbor_row.append(species_name)

    # append neighbors row to main data list
    data_neighbors.append(neighbor_row)

cols = [
    'Orignal_Recording', 'Original_Distance', 'Original_Common_Name',
    '1st_Neighbor_Recording', '1st_Neighbor_Distance', '1st_Neighbor_Common_Name',
    '2nd_Neighbor_Recording', '2nd_Neighbor_Distance', '2nd_Neighbor_Common_Name',
    '3rd_Neighbor_Recording', '3rd_Neighbor_Distance', '3rd_Neighbor_Common_Name',
    '4th_Neighbor_Recording', '4th_Neighbor_Distance', '4th_Neighbor_Common_Name',
    '5th_Neighbor_Recording', '5th_Neighbor_Distance', '5th_Neighbor_Common_Name']

df_neighbors = pd.DataFrame(data_neighbors, columns=cols)
df_neighbors.head(20)
# Out:
#    Orignal_Recording  Original_Distance           Original_Common_Name  \
# 0          32323.wav                0.0                   Grey Elaenia
# 1          75536.wav                0.0                    Yucatan Jay
# 2          64694.wav                0.0               Identity unknown
# 3          33404.wav                0.0                 Wattled Jacana
# 4          22500.wav                0.0                  Common Cuckoo
# 5          32665.wav                0.0        White-breasted Tapaculo
# 6          75680.wav                0.0                      Tawny Owl
# 7          64803.wav                0.0               Identity unknown
# 8          10955.wav                0.0           African Hill Babbler
# 9          64585.wav                0.0         Golden-crowned Warbler
# 10         43712.wav                0.0                      Great Tit
# 11         11845.wav                0.0         Eye-ringed Tody-Tyrant
# 12         54098.wav                0.0        Scissor-tailed Nightjar
# 13         75216.wav                0.0  Northern White-crowned Shrike
# 14         21947.wav                0.0                Western Tanager
# 15         32232.wav                0.0               Tufted Antshrike
# 16         32724.wav                0.0              Red-gartered Coot
# 17         33537.wav                0.0         Rusty-vented Canastero
# 18         22444.wav                0.0          White-bellied Antbird
# 19         53970.wav                0.0               Identity unknown
#
#    1st_Neighbor_Recording  1st_Neighbor_Distance  1st_Neighbor_Common_Name  \
# 0               43289.wav               0.309872            Black Redstart
# 1               43625.wav               0.402583           Common Redstart
# 2               64961.wav               0.487772                   Redwing
# 3               33233.wav               0.242899       Blue-necked Jacamar
# 4               22498.wav               0.432251             Common Cuckoo
# 5               64461.wav               0.000000              Green Hermit
# 6               75681.wav               0.383017                 Tawny Owl
# 7               22847.wav               0.345776     Yellow-browed Warbler
# 8                 306.wav               0.528227         Singing Cisticola
# 9               43686.wav               0.709176    Short-tailed Antthrush
# 10              54125.wav               0.286981                 Great Tit
# 11              75665.wav               0.411535           Brown Wood Rail
# 12              53770.wav               0.586288        Buff-bellied Pipit
# 13              43265.wav               0.516891                 Great Tit
# 14              21643.wav               0.610238                   Limpkin
# 15              75460.wav               0.515845        Blue-headed Parrot
# 16              54624.wav               0.263288  Blue-billed Black Tyrant
# 17              33527.wav               0.280888          Canyon Canastero
# 18              43144.wav               0.432960   Black-headed Brushfinch
# 19              11830.wav               0.594527        Euler's Flycatcher
#
#    2nd_Neighbor_Recording  2nd_Neighbor_Distance  \
# 0               21584.wav               0.347843
# 1               43991.wav               0.464861
# 2               64832.wav               0.487772
# 3               33405.wav               0.264780
# 4               22497.wav               0.552739
# 5               64681.wav               0.000000
# 6               22490.wav               0.675619
# 7               21889.wav               0.345776
# 8               43450.wav               0.548254
# 9                  72.wav               0.713998
# 10              43711.wav               0.300143
# 11              11886.wav               0.428476
# 12              54033.wav               0.607186
# 13              53818.wav               0.560678
# 14              10825.wav               0.686980
# 15              75538.wav               0.536900
# 16              32548.wav               0.281280
# 17              22000.wav               0.280888
# 18              43869.wav               0.482767
# 19              33556.wav               0.598963
#
#            2nd_Neighbor_Common_Name 3rd_Neighbor_Recording  \
# 0                 Bridled White-eye              32307.wav
# 1                     House Sparrow               1145.wav
# 2                           Redwing              21946.wav
# 3                    Wattled Jacana              33078.wav
# 4                     Common Cuckoo              54363.wav
# 5                      Green Hermit              32995.wav
# 6                         Tawny Owl              43959.wav
# 7             Yellow-browed Warbler                818.wav
# 8          Dusky-throated Antshrike                861.wav
# 9                Siberian Stonechat              64545.wav
# 10                        Great Tit              43702.wav
# 11                    Large Elaenia              11963.wav
# 12                    Bewick's Wren              54472.wav
# 13               Spotted Honeyguide              54560.wav
# 14                    House Sparrow              43051.wav
# 15                       Sunbittern              11170.wav
# 16             Tropical Screech Owl              32550.wav
# 17  Black-billed Nightingale-Thrush              33535.wav
# 18                 Identity unknown              43501.wav
# 19              Speckled Chachalaca               1282.wav
#
#     3rd_Neighbor_Distance     3rd_Neighbor_Common_Name 4th_Neighbor_Recording  \
# 0                0.361734       Short-billed Canastero              54667.wav
# 1                0.482391       Clamorous Reed Warbler              33207.wav
# 2                0.568243        White-throated Towhee              43573.wav
# 3                0.325468                   Barred Owl              33280.wav
# 4                0.588764            Pied-billed Grebe              32894.wav
# 5                0.130300  Serra do Mar Tyrant-Manakin              43773.wav
# 6                0.684558                    Tawny Owl              75878.wav
# 7                0.383954            Cabanis's Bunting              54265.wav
# 8                0.558986          Black-winged Oriole               1018.wav
# 9                0.716248               Meadow Bunting              75820.wav
# 10               0.303705                    Great Tit              43525.wav
# 11               0.438289           Euler's Flycatcher              53943.wav
# 12               0.662020           Western Meadowlark              54438.wav
# 13               0.571139        Yellow-spotted Barbet              11081.wav
# 14               0.686980    White-throated Tyrannulet                 22.wav
# 15               0.540154     Brown-winged Schiffornis              10969.wav
# 16               0.335702         Tropical Screech Owl              32557.wav
# 17               0.291528       Rusty-vented Canastero              33510.wav
# 18               0.482767             Identity unknown              43976.wav
# 19               0.616983              Spangled Drongo              11904.wav
#
#     4th_Neighbor_Distance   4th_Neighbor_Common_Name 5th_Neighbor_Recording  \
# 0                0.364576       Grey-collared Becard              64913.wav
# 1                0.509303          Grey-fronted Dove              75456.wav
# 2                0.588080                 Ring Ouzel              43856.wav
# 3                0.327791  Stripe-necked Tody-Tyrant              33210.wav
# 4                0.642222              Common Cuckoo              11052.wav
# 5                0.441383      Rufous-bellied Thrush              32738.wav
# 6                0.689460      European Storm Petrel              53813.wav
# 7                0.418559          Zitting Cisticola              33760.wav
# 8                0.594777       African Hill Babbler                678.wav
# 9                0.742124        Blue-necked Jacamar              10907.wav
# 10               0.308405                  Great Tit              43701.wav
# 11               0.448849         Carolina Chickadee              11287.wav
# 12               0.662450         Buff-bellied Pipit              33128.wav
# 13               0.581460              Dusky Antbird              32986.wav
# 14               0.705826  Lesser Spotted Woodpecker              10841.wav
# 15               0.560107        Smoke-colored Pewee              11086.wav
# 16               0.384363            Squirrel Cuckoo              32725.wav
# 17               0.360953   Creamy-crested Spinetail              33492.wav
# 18               0.483852    Snowy-browed Flycatcher              44011.wav
# 19               0.628506      Plain-crested Elaenia              21533.wav
#
#     5th_Neighbor_Distance 5th_Neighbor_Common_Name
# 0                0.375718    Red-breasted Nuthatch
# 1                0.510597     Blue-black Grassquit
# 2                0.588646         Identity unknown
# 3                0.370849    Flame-crested Tanager
# 4                0.673244     White-mantled Barbet
# 5                0.524517     Temminck's Seedeater
# 6                0.771804     Tropical Screech Owl
# 7                0.418559        Zitting Cisticola
# 8                0.596339              Grey Apalis
# 9                0.743617      White-crowned Shama
# 10               0.312025                Great Tit
# 11               0.477490    Swainson's Flycatcher
# 12               0.664635          Variable Oriole
# 13               0.595359          Plumbeous Vireo
# 14               0.713204      Common House Martin
# 15               0.566235    Rufous-bellied Thrush
# 16               0.396951        Red-gartered Coot
# 17               0.384123          Pacific Hornero
# 18               0.505632         Identity unknown
# 19               0.636607       Rio Branco Antbird

# %%
df_neighbors.sort_values(['1st_Neighbor_Distance'], ascending=[True]).head(20)
# Out:
#      Orignal_Recording  Original_Distance       Original_Common_Name  \
# 1121         21878.wav                0.0              Dusky Warbler
# 2599         32327.wav                0.0      Thorn-tailed Rayadito
# 402          33284.wav                0.0     Rufous-breasted Hermit
# 2099         22052.wav                0.0           Greenish Elaenia
# 2600         21711.wav                0.0           Klages's Antbird
# 2605         64883.wav                0.0           Identity unknown
# 397          33278.wav                0.0  White-bellied Hummingbird
# 1047         43854.wav                0.0           Identity unknown
# 2087         43250.wav                0.0   Great Spotted Woodpecker
# 394           1103.wav                0.0   Black-chested Fruiteater
# 2084         43688.wav                0.0           Identity unknown
# 2083         54053.wav                0.0           Northern Pintail
# 1069         22283.wav                0.0    Grey-backed Camaroptera
# 1071         21808.wav                0.0       Tropical Gnatcatcher
# 1073           485.wav                0.0   Chestnut-tipped Toucanet
# 1074            27.wav                0.0               Little Stint
# 376          22431.wav                0.0            Common Redstart
# 375          22201.wav                0.0        Violet-tailed Sylph
# 2057         65068.wav                0.0                 Soundscape
# 1084          1097.wav                0.0          Barred Fruiteater
#
#      1st_Neighbor_Recording  1st_Neighbor_Distance  1st_Neighbor_Common_Name  \
# 1121              22260.wav                    0.0             Mistle Thrush
# 2599              32328.wav                    0.0     Thorn-tailed Rayadito
# 402               33034.wav                    0.0              Plain Pigeon
# 2099              11791.wav                    0.0          Greenish Elaenia
# 2600               1106.wav                    0.0  Black-chested Fruiteater
# 2605              64884.wav                    0.0          Identity unknown
# 397               22246.wav                    0.0      Tropical Gnatcatcher
# 1047              43741.wav                    0.0          Identity unknown
# 2087              64745.wav                    0.0  Great Spotted Woodpecker
# 394               12097.wav                    0.0      Brown-headed Cowbird
# 2084              64375.wav                    0.0          Identity unknown
# 2083              75487.wav                    0.0          Northern Pintail
# 1069                650.wav                    0.0   Grey-backed Camaroptera
# 1071              11208.wav                    0.0      Tropical Gnatcatcher
# 1073              32617.wav                    0.0             Scaled Pigeon
# 1074              75371.wav                    0.0              Little Stint
# 376               43150.wav                    0.0           Common Redstart
# 375               22200.wav                    0.0       Violet-tailed Sylph
# 2057              64928.wav                    0.0                Soundscape
# 1084               1098.wav                    0.0         Barred Fruiteater
#
#      2nd_Neighbor_Recording  2nd_Neighbor_Distance   2nd_Neighbor_Common_Name  \
# 1121               1164.wav               0.269473           White-eyed Vireo
# 2599              32302.wav               0.187475             Puna Canastero
# 402               54210.wav               0.514941           Western Barn Owl
# 2099              33016.wav               0.420234   Black-tailed Gnatcatcher
# 2600               1109.wav               0.000000   Black-chested Fruiteater
# 2605              64581.wav               0.000000           Identity unknown
# 397               11206.wav               0.000000       Tropical Gnatcatcher
# 1047              43871.wav               0.489304           Ashy Woodswallow
# 2087               1039.wav               0.516036          Sardinian Warbler
# 394                1108.wav               0.000000   Black-chested Fruiteater
# 2084              43783.wav               0.000000           Identity unknown
# 2083              10947.wav               0.487954   Northern Grosbeak-Canary
# 1069              43448.wav               0.249667   Dusky-throated Antshrike
# 1071              75370.wav               0.444964               Little Stint
# 1073              42997.wav               0.000000                 Ring Ouzel
# 1074              32398.wav               0.000000         St. Vincent Amazon
# 376               32937.wav               0.543280            Scarlet Tanager
# 375               64658.wav               0.467946       Archbold's Bowerbird
# 2057              65067.wav               0.206364                 Soundscape
# 1084              65251.wav               0.000000  Slaty-capped Shrike-Vireo
#
#      3rd_Neighbor_Recording  3rd_Neighbor_Distance  \
# 1121              54145.wav               0.494513
# 2599              54151.wav               0.222607
# 402                1003.wav               0.514941
# 2099              75918.wav               0.491456
# 2600              21727.wav               0.240314
# 2605              11715.wav               0.275366
# 397               21720.wav               0.366909
# 1047              43740.wav               0.498447
# 2087              44003.wav               0.539580
# 394                1102.wav               0.000000
# 2084              10927.wav               0.543321
# 2083              10946.wav               0.489952
# 1069              22135.wav               0.250574
# 1071              22282.wav               0.459503
# 1073              22466.wav               0.573091
# 1074              75129.wav               0.380387
# 376               32861.wav               0.648029
# 375               43077.wav               0.525612
# 2057              65078.wav               0.258080
# 1084              21898.wav               0.394306
#
#         3rd_Neighbor_Common_Name 4th_Neighbor_Recording  \
# 1121                 Surf Scoter              43062.wav
# 2599        Yellow-bridled Finch              43988.wav
# 402   Yellow-browed Shrike-Vireo              64767.wav
# 2099           Sardinian Warbler               1179.wav
# 2600     Orange-bellied Euphonia              21691.wav
# 2605    Many-colored Rush Tyrant              64530.wav
# 397       Yellow-bellied Elaenia              22268.wav
# 1047             Eurasian Hoopoe              43983.wav
# 2087          Common Nightingale              32406.wav
# 394     Black-chested Fruiteater               1084.wav
# 2084               Common Cuckoo               1140.wav
# 2083    Northern Grosbeak-Canary              54016.wav
# 1069             Lita Woodpecker                267.wav
# 1071          Grey-backed Fiscal              22489.wav
# 1073      European Golden Plover              22474.wav
# 1074        Square-tailed Drongo              22723.wav
# 376              Common Redstart              75849.wav
# 375        Hairy-crested Antbird              21635.wav
# 2057                  Soundscape              65079.wav
# 1084              Boucard's Wren              53779.wav
#
#       4th_Neighbor_Distance   4th_Neighbor_Common_Name 5th_Neighbor_Recording  \
# 1121               0.579161                 Soundscape              10786.wav
# 2599               0.223795           Greenish Elaenia              32375.wav
# 402                0.514941          Buffy Tuftedcheek              11439.wav
# 2099               0.492126                 House Crow              32426.wav
# 2600               0.396717  Guttulate Foliage-gleaner              21766.wav
# 2605               0.328848           Solitary Cacique              75623.wav
# 397                0.469032           Southern Lapwing              21742.wav
# 1047               0.508817           Identity unknown              43501.wav
# 2087               0.584060          Robust Woodpecker              33015.wav
# 394                0.462116   White-browed Hemispingus              11650.wav
# 2084               0.574343           Indian Cormorant              11080.wav
# 2083               0.568592   Black-tailed Gnatcatcher              43820.wav
# 1069               0.378835       Square-tailed Drongo                864.wav
# 1071               0.472333                  Tawny Owl              11736.wav
# 1073               0.583109           Lapland Longspur              22475.wav
# 1074               0.407924             Scaled Antbird              22356.wav
# 376                0.723644    Snowy-browed Flycatcher              21695.wav
# 375                0.581080             Screaming Piha               1305.wav
# 2057               0.325797                 Soundscape              65080.wav
# 1084               0.395833                Horned Lark              54400.wav
#
#       5th_Neighbor_Distance     5th_Neighbor_Common_Name
# 1121               0.586785         Fernandina's Flicker
# 2599               0.255573  Scale-throated Earthcreeper
# 402                0.518499           Grey-hooded Attila
# 2099               0.507906    Yellow-fronted Woodpecker
# 2600               0.437228                   Sunbittern
# 2605               0.389817             Chukar Partridge
# 397                0.478700         Tropical Screech Owl
# 1047               0.585495             Identity unknown
# 2087               0.587453     Black-tailed Gnatcatcher
# 394                0.534631               Urrao Antpitta
# 2084               0.574343        Rufous-bellied Thrush
# 2083               0.571828             Identity unknown
# 1069               0.425527          Black-winged Oriole
# 1071               0.478106              Bearded Tachuri
# 1073               0.614676             Lapland Longspur
# 1074               0.506236            Eurasian Blackcap
# 376                0.750720    Scallop-breasted Antpitta
# 375                0.590730                 Manu Antbird
# 2057               0.384815                   Soundscape
# 1084               0.447997                Bewick's Wren

# %%
orig_and_first = df_neighbors[[
    'Original_Common_Name', 
    '1st_Neighbor_Common_Name', 
    '2nd_Neighbor_Common_Name',
    '3rd_Neighbor_Common_Name',
    '4th_Neighbor_Common_Name',
    '5th_Neighbor_Common_Name'
]].values

num_matches = np.where(
    (orig_and_first[:, 0] == orig_and_first[:, 1]) 
    | (orig_and_first[:, 0] == orig_and_first[:, 2])
    | (orig_and_first[:, 0] == orig_and_first[:, 3])
    | (orig_and_first[:, 0] == orig_and_first[:, 4])
    | (orig_and_first[:, 0] == orig_and_first[:, 5])
)
top_5_accuracy = num_matches[0].shape[0] / orig_and_first.shape[0]
top_5_accuracy
# Out:
# 0.3790893760539629
